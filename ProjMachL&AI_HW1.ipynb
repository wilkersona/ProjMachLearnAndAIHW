# %% [markdown]
# 1. I would like to solve a problem in image recognition, particularly whether an image contains a certain object. I have not decided on the exact object yet, as I would like to leave my options open for choosing a dataset. Logistic Regression would be a good way to solve this problem, as you can feed the algorithm the individual RBG color value, and have it output the binary choice of if the image contains said object or not.

# %% [markdown]
# 2. I chose to use a dataset that contains data about images of oranges and grapefruits.
#
# [Link: https://www.kaggle.com/joshmcadams/oranges-vs-grapefruit ]
#
# This dataset has 10,000 points, equally distributed between the two groups, and contains data about their diameter and weight. What is nice about this dataset is that it has also already extracted all the RGB color values from the picture, and simply lists them as their average. The red values tend to be near 150, the green near 75, and the blue near 0, which is around what one would expect of both fruits. Additionally, there are no missing or invalid data points, nor does there seem to be any significant outliers. I sorted each of the values for each type of fruit, and none of the maximum or minimum values seemed statistically improbable enough to remove. Overall, the dataset is essentially ready-to-go when downloaded, which is why I"m glad I kept my options open in problem #1.

# %%
# Import TensorFlow, Pandas, and Numpy
import tensorflow as tf
import pandas as pd
import numpy as np
import math

#read in data and print first few values
data = pd.read_csv('citrus.csv')
data.head()

#initialize weights and b
weights = np.array([0,0,0,0,0])
b_val = 0


def evaluateSigmoid(value):
  return (1/(1 + pow(math.e, -1*value)))

#initialize data
X = data[['diameter', 'weight', 'red', 'green', 'blue']]
Y = []
for name in data['name']:
  if name=='orange':
    Y.append(1)
  else:
    Y.append(0)
Y = np.array(Y)

#3.)
#Variation 1: Vanilla Gradient Descent
num_epochs = 350;
learning_rate = 0.01;
for epoch in range(num_epochs):
  A = evaluateSigmoid(np.dot(weights,X.T) + b_val)
  #I had to change the 1 in the second portion to 1.000001 in case A = 1
  cost=-1/len(Y) * np.sum(Y * np.log(A) + (1-Y) * (np.log(1.000001-A)))
  dw = np.dot(X.T, (A-Y).T)/len(Y)
  db= np.sum(A-Y)/len(Y)
  weights = weights - learning_rate*dw
  b_val = b_val - learning_rate*db
  print('Batch Gradient Descent Epoch: '+str(epoch)+'   Cost: '+str(cost))

#Variation 2: Stochastic Gradient Descent
num_epochs = 1 
for epoch in range(num_epochs):
  for i in range(len(Y)):
    A = evaluateSigmoid(np.dot(weights,X[i:i+1].T) + b_val)
    dw = np.dot(X[i:i+1].T, (A-Y[i:i+1]).T)/len(Y)
    db= np.sum(A-Y[i:i+1])/len(Y)
    weights = weights - learning_rate*dw
    b_val = b_val - learning_rate*db
  A = evaluateSigmoid(np.dot(weights,X.T) + b_val)
  #I had to change the 1 in the second portion to 1.000001 in case A = 1
  cost=-1/len(Y) * np.sum(Y * np.log(A) + (1-Y) * (np.log(1.000001-A)))
  print('Stochastic Gradient Descent Epoch: '+str(epoch)+'   Cost: '+str(cost))

#4.)
#Optimization 1: Momentum
num_epochs = 150;
momentum_w = np.array([0,0,0,0,0]);
momentum_b=0;
momentum_const=0.9
for epoch in range(num_epochs):
  A = evaluateSigmoid(np.dot(weights,X.T) + b_val)
  #I had to change the 1 in the second portion to 1.000001 in case A = 1
  cost=-1/len(Y) * np.sum(Y * np.log(A) + (1-Y) * (np.log(1.000001-A)))
  dw = np.dot(X.T, (A-Y).T)/len(Y)
  db= np.sum(A-Y)/len(Y)
  momentum_w = momentum_const*momentum_w + learning_rate*dw
  momentum_b = momentum_const*momentum_b + learning_rate*db
  weights = weights - momentum_w
  b_val = b_val - momentum_b
  print('Momentum Gradient Descent Epoch: '+str(epoch)+'   Cost: '+str(cost))

#Optimization 2: Nesterov
num_epochs = 150;
momentum_w = np.array([0,0,0,0,0]);
momentum_b=0;
for epoch in range(num_epochs):
  A = evaluateSigmoid(np.dot((weights-momentum_const*momentum_w),X.T) + b_val-momentum_const*momentum_b)
  #I had to change the 1 in the second portion to 1.000001 in case A = 1
  cost=-1/len(Y) * np.sum(Y * np.log(A) + (1-Y) * (np.log(1.000001-A)))
  dw = np.dot(X.T, (A-Y).T)/len(Y)
  db= np.sum(A-Y)/len(Y)
  momentum_w = momentum_const*momentum_w + learning_rate*dw
  momentum_b = momentum_const*momentum_b + learning_rate*db
  weights = weights - momentum_w
  b_val = b_val - momentum_b
  print('Nesterov Gradient Descent Epoch: '+str(epoch)+'   Cost: '+str(cost))
# Out:
# Batch Gradient Descent Epoch: 0   Cost: 0.6931461805609453
# Batch Gradient Descent Epoch: 1   Cost: 6.209987755714926
# Batch Gradient Descent Epoch: 2   Cost: 6.907755279023269
# Batch Gradient Descent Epoch: 3   Cost: 18.634564701547788
# Batch Gradient Descent Epoch: 4   Cost: 6.907755279023269
# Batch Gradient Descent Epoch: 5   Cost: 31.054503788242314
# Batch Gradient Descent Epoch: 6   Cost: 6.907755279023269
# Batch Gradient Descent Epoch: 7   Cost: 43.47444284233938
# Batch Gradient Descent Epoch: 8   Cost: 6.907755279023269
# Batch Gradient Descent Epoch: 9   Cost: 55.89438189643386
# Batch Gradient Descent Epoch: 10   Cost: 6.907755279023269
# Batch Gradient Descent Epoch: 11   Cost: 68.31432095052838
# Batch Gradient Descent Epoch: 12   Cost: 6.907755279023269
# Batch Gradient Descent Epoch: 13   Cost: 80.73426000462287
# Batch Gradient Descent Epoch: 14   Cost: 6.9037799435697575
# Batch Gradient Descent Epoch: 15   Cost: 93.12326372749679
# Batch Gradient Descent Epoch: 16   Cost: 5.766489708347084
# Batch Gradient Descent Epoch: 17   Cost: 90.56889453166696
# Batch Gradient Descent Epoch: 18   Cost: 5.428519357189459
# Batch Gradient Descent Epoch: 19   Cost: 81.8819931995306
# Batch Gradient Descent Epoch: 20   Cost: 6.084296004051948
# Batch Gradient Descent Epoch: 21   Cost: 82.54697135517499
# Batch Gradient Descent Epoch: 22   Cost: 5.3435656609499835
# Batch Gradient Descent Epoch: 23   Cost: 70.57561349863377
# Batch Gradient Descent Epoch: 24   Cost: 6.26266975750079
# Batch Gradient Descent Epoch: 25   Cost: 73.3181637118448
# Batch Gradient Descent Epoch: 26   Cost: 5.446933554561482
# Batch Gradient Descent Epoch: 27   Cost: 62.01483935494787
# Batch Gradient Descent Epoch: 28   Cost: 6.165952257640455
# Batch Gradient Descent Epoch: 29   Cost: 62.73373203103978
# Batch Gradient Descent Epoch: 30   Cost: 5.636754820615692
# Batch Gradient Descent Epoch: 31   Cost: 54.6088424098387
# Batch Gradient Descent Epoch: 32   Cost: 5.901242393539073
# Batch Gradient Descent Epoch: 33   Cost: 52.00635525613042
# Batch Gradient Descent Epoch: 34   Cost: 5.645619390442366
# Batch Gradient Descent Epoch: 35   Cost: 46.1196250688353
# Batch Gradient Descent Epoch: 36   Cost: 5.636418583855944
# Batch Gradient Descent Epoch: 37   Cost: 42.18113708297617
# Batch Gradient Descent Epoch: 38   Cost: 5.398406584075355
# Batch Gradient Descent Epoch: 39   Cost: 36.42158534280627
# Batch Gradient Descent Epoch: 40   Cost: 5.132911390141584
# Batch Gradient Descent Epoch: 41   Cost: 31.315280641216706
# Batch Gradient Descent Epoch: 42   Cost: 4.784420175617276
# Batch Gradient Descent Epoch: 43   Cost: 25.676739572463852
# Batch Gradient Descent Epoch: 44   Cost: 4.270323894952483
# Batch Gradient Descent Epoch: 45   Cost: 19.803540473189276
# Batch Gradient Descent Epoch: 46   Cost: 3.5864643864140753
# Batch Gradient Descent Epoch: 47   Cost: 13.559137957777098
# Batch Gradient Descent Epoch: 48   Cost: 2.682344796478625
# Batch Gradient Descent Epoch: 49   Cost: 7.316485231851573
# Batch Gradient Descent Epoch: 50   Cost: 1.7998142111138333
# Batch Gradient Descent Epoch: 51   Cost: 3.510982498982403
# Batch Gradient Descent Epoch: 52   Cost: 1.383475010707393
# Batch Gradient Descent Epoch: 53   Cost: 2.0490286774296465
# Batch Gradient Descent Epoch: 54   Cost: 1.5045924510402284
# Batch Gradient Descent Epoch: 55   Cost: 1.7145673294535169
# Batch Gradient Descent Epoch: 56   Cost: 1.6132143951255895
# Batch Gradient Descent Epoch: 57   Cost: 1.6557237415656496
# Batch Gradient Descent Epoch: 58   Cost: 1.6317384672582471
# Batch Gradient Descent Epoch: 59   Cost: 1.6383519658214647
# Batch Gradient Descent Epoch: 60   Cost: 1.6309228755028213
# Batch Gradient Descent Epoch: 61   Cost: 1.62999338803376
# Batch Gradient Descent Epoch: 62   Cost: 1.6260674879912214
# Batch Gradient Descent Epoch: 63   Cost: 1.623546072105269
# Batch Gradient Descent Epoch: 64   Cost: 1.6203821144259378
# Batch Gradient Descent Epoch: 65   Cost: 1.6175300895443219
# Batch Gradient Descent Epoch: 66   Cost: 1.6145432721904331
# Batch Gradient Descent Epoch: 67   Cost: 1.6116309477398785
# Batch Gradient Descent Epoch: 68   Cost: 1.6086944540175239
# Batch Gradient Descent Epoch: 69   Cost: 1.605780067463081
# Batch Gradient Descent Epoch: 70   Cost: 1.6028656810434831
# Batch Gradient Descent Epoch: 71   Cost: 1.5999615299855288
# Batch Gradient Descent Epoch: 72   Cost: 1.5970625165033163
# Batch Gradient Descent Epoch: 73   Cost: 1.594170825602219
# Batch Gradient Descent Epoch: 74   Cost: 1.5912851712765992
# Batch Gradient Descent Epoch: 75   Cost: 1.5884059201871443
# Batch Gradient Descent Epoch: 76   Cost: 1.5855326445140605
# Batch Gradient Descent Epoch: 77   Cost: 1.5826652930129477
# Batch Gradient Descent Epoch: 78   Cost: 1.579803629431235
# Batch Gradient Descent Epoch: 79   Cost: 1.5769475026942001
# Batch Gradient Descent Epoch: 80   Cost: 1.5740967171101212
# Batch Gradient Descent Epoch: 81   Cost: 1.5712510955274512
# Batch Gradient Descent Epoch: 82   Cost: 1.5684104493699158
# Batch Gradient Descent Epoch: 83   Cost: 1.5655745939210468
# Batch Gradient Descent Epoch: 84   Cost: 1.5627433418038916
# Batch Gradient Descent Epoch: 85   Cost: 1.5599165072837613
# Batch Gradient Descent Epoch: 86   Cost: 1.5570939055271065
# Batch Gradient Descent Epoch: 87   Cost: 1.5542753545947332
# Batch Gradient Descent Epoch: 88   Cost: 1.5514606763844567
# Batch Gradient Descent Epoch: 89   Cost: 1.548649698398434
# Batch Gradient Descent Epoch: 90   Cost: 1.545842255418984
# Batch Gradient Descent Epoch: 91   Cost: 1.5430381915517457
# Batch Gradient Descent Epoch: 92   Cost: 1.5402373624110886
# Batch Gradient Descent Epoch: 93   Cost: 1.5374396375464008
# Batch Gradient Descent Epoch: 94   Cost: 1.534644903042408
# Batch Gradient Descent Epoch: 95   Cost: 1.531853064290677
# Batch Gradient Descent Epoch: 96   Cost: 1.5290640488830822
# Batch Gradient Descent Epoch: 97   Cost: 1.5262778095681733
# Batch Gradient Descent Epoch: 98   Cost: 1.5234943271948804
# Batch Gradient Descent Epoch: 99   Cost: 1.520713613542311
# Batch Gradient Descent Epoch: 100   Cost: 1.5179357139136849
# Batch Gradient Descent Epoch: 101   Cost: 1.5151607093533457
# Batch Gradient Descent Epoch: 102   Cost: 1.512388718328296
# Batch Gradient Descent Epoch: 103   Cost: 1.509619897710148
# Batch Gradient Descent Epoch: 104   Cost: 1.5068544428902189
# Batch Gradient Descent Epoch: 105   Cost: 1.50409258687448
# Batch Gradient Descent Epoch: 106   Cost: 1.5013345982330695
# Batch Gradient Descent Epoch: 107   Cost: 1.4985807778198588
# Batch Gradient Descent Epoch: 108   Cost: 1.4958314542267477
# Batch Gradient Descent Epoch: 109   Cost: 1.4930869780104163
# Batch Gradient Descent Epoch: 110   Cost: 1.490347714793336
# Batch Gradient Descent Epoch: 111   Cost: 1.4876140374185456
# Batch Gradient Descent Epoch: 112   Cost: 1.4848863174029718
# Batch Gradient Descent Epoch: 113   Cost: 1.482164915992239
# Batch Gradient Descent Epoch: 114   Cost: 1.4794501751536913
# Batch Gradient Descent Epoch: 115   Cost: 1.4767424088695873
# Batch Gradient Descent Epoch: 116   Cost: 1.4740418950776075
# Batch Gradient Descent Epoch: 117   Cost: 1.4713488685835916
# Batch Gradient Descent Epoch: 118   Cost: 1.468663515217323
# Batch Gradient Descent Epoch: 119   Cost: 1.4659859674369016
# Batch Gradient Descent Epoch: 120   Cost: 1.463316301510614
# Batch Gradient Descent Epoch: 121   Cost: 1.4606545363306427
# Batch Gradient Descent Epoch: 122   Cost: 1.4580006338238627
# Batch Gradient Descent Epoch: 123   Cost: 1.4553545008677606
# Batch Gradient Descent Epoch: 124   Cost: 1.4527159925546922
# Batch Gradient Descent Epoch: 125   Cost: 1.4500849166063
# Batch Gradient Descent Epoch: 126   Cost: 1.447461038713654
# Batch Gradient Descent Epoch: 127   Cost: 1.4448440885618319
# Batch Gradient Descent Epoch: 128   Cost: 1.4422337663055502
# Batch Gradient Descent Epoch: 129   Cost: 1.4396297492583177
# Batch Gradient Descent Epoch: 130   Cost: 1.4370316985982354
# Batch Gradient Descent Epoch: 131   Cost: 1.4344392658875569
# Batch Gradient Descent Epoch: 132   Cost: 1.4318520992593995
# Batch Gradient Descent Epoch: 133   Cost: 1.4292698491295142
# Batch Gradient Descent Epoch: 134   Cost: 1.4266921733284492
# Batch Gradient Descent Epoch: 135   Cost: 1.424118741577685
# Batch Gradient Descent Epoch: 136   Cost: 1.4215492392532874
# Batch Gradient Descent Epoch: 137   Cost: 1.4189833704107204
# Batch Gradient Descent Epoch: 138   Cost: 1.4164208600707886
# Batch Gradient Descent Epoch: 139   Cost: 1.4138614557825087
# Batch Gradient Descent Epoch: 140   Cost: 1.4113049285085009
# Batch Gradient Descent Epoch: 141   Cost: 1.4087510728904529
# Batch Gradient Descent Epoch: 142   Cost: 1.406199706970127
# Batch Gradient Descent Epoch: 143   Cost: 1.4036506714471588
# Batch Gradient Descent Epoch: 144   Cost: 1.4011038285656672
# Batch Gradient Descent Epoch: 145   Cost: 1.3985590607122207
# Batch Gradient Descent Epoch: 146   Cost: 1.396016268813228
# Batch Gradient Descent Epoch: 147   Cost: 1.3934753706061578
# Batch Gradient Descent Epoch: 148   Cost: 1.3909362988506813
# Batch Gradient Descent Epoch: 149   Cost: 1.388398999537216
# Batch Gradient Descent Epoch: 150   Cost: 1.3858634301397814
# Batch Gradient Descent Epoch: 151   Cost: 1.383329557950887
# Batch Gradient Descent Epoch: 152   Cost: 1.3807973585277187
# Batch Gradient Descent Epoch: 153   Cost: 1.3782668142766223
# Batch Gradient Descent Epoch: 154   Cost: 1.3757379131931227
# Batch Gradient Descent Epoch: 155   Cost: 1.3732106477804373
# Batch Gradient Descent Epoch: 156   Cost: 1.370685014157069
# Batch Gradient Descent Epoch: 157   Cost: 1.3681610113689617
# Batch Gradient Descent Epoch: 158   Cost: 1.3656386409274
# Batch Gradient Descent Epoch: 159   Cost: 1.3631179065745445
# Batch Gradient Descent Epoch: 160   Cost: 1.3605988142974454
# Batch Gradient Descent Epoch: 161   Cost: 1.358081372597009
# Batch Gradient Descent Epoch: 162   Cost: 1.3555655930158403
# Batch Gradient Descent Epoch: 163   Cost: 1.3530514909321971
# Batch Gradient Descent Epoch: 164   Cost: 1.3505390866039702
# Batch Gradient Descent Epoch: 165   Cost: 1.3480284064578856
# Batch Gradient Descent Epoch: 166   Cost: 1.3455194845876
# Batch Gradient Descent Epoch: 167   Cost: 1.3430123644244814
# Batch Gradient Descent Epoch: 168   Cost: 1.340507100520213
# Batch Gradient Descent Epoch: 169   Cost: 1.3380037603700288
# Batch Gradient Descent Epoch: 170   Cost: 1.3355024261827089
# Batch Gradient Descent Epoch: 171   Cost: 1.3330031964958837
# Batch Gradient Descent Epoch: 172   Cost: 1.3305061875210416
# Batch Gradient Descent Epoch: 173   Cost: 1.328011534100409
# Batch Gradient Descent Epoch: 174   Cost: 1.3255193901676294
# Batch Gradient Descent Epoch: 175   Cost: 1.3230299286145117
# Batch Gradient Descent Epoch: 176   Cost: 1.3205433404960263
# Batch Gradient Descent Epoch: 177   Cost: 1.3180598335458078
# Batch Gradient Descent Epoch: 178   Cost: 1.3155796300114846
# Batch Gradient Descent Epoch: 179   Cost: 1.3131029638725642
# Batch Gradient Descent Epoch: 180   Cost: 1.3106300775496984
# Batch Gradient Descent Epoch: 181   Cost: 1.3081612182517266
# Batch Gradient Descent Epoch: 182   Cost: 1.3056966341387606
# Batch Gradient Descent Epoch: 183   Cost: 1.303236570493369
# Batch Gradient Descent Epoch: 184   Cost: 1.3007812660896043
# Batch Gradient Descent Epoch: 185   Cost: 1.298330949926734
# Batch Gradient Descent Epoch: 186   Cost: 1.295885838471146
# Batch Gradient Descent Epoch: 187   Cost: 1.2934461334974048
# Batch Gradient Descent Epoch: 188   Cost: 1.2910120205729372
# Batch Gradient Descent Epoch: 189   Cost: 1.2885836681929648
# Batch Gradient Descent Epoch: 190   Cost: 1.286161227515164
# Batch Gradient Descent Epoch: 191   Cost: 1.2837448326204757
# Batch Gradient Descent Epoch: 192   Cost: 1.281334601200163
# Batch Gradient Descent Epoch: 193   Cost: 1.2789306355519643
# Batch Gradient Descent Epoch: 194   Cost: 1.2765330237756642
# Batch Gradient Descent Epoch: 195   Cost: 1.274141841056078
# Batch Gradient Descent Epoch: 196   Cost: 1.2717571509425039
# Batch Gradient Descent Epoch: 197   Cost: 1.2693790065445163
# Batch Gradient Descent Epoch: 198   Cost: 1.267007451589902
# Batch Gradient Descent Epoch: 199   Cost: 1.264642521304534
# Batch Gradient Descent Epoch: 200   Cost: 1.2622842430960783
# Batch Gradient Descent Epoch: 201   Cost: 1.259932637037234
# Batch Gradient Descent Epoch: 202   Cost: 1.257587716153652
# Batch Gradient Descent Epoch: 203   Cost: 1.2552494865416028
# Batch Gradient Descent Epoch: 204   Cost: 1.252917947329211
# Batch Gradient Descent Epoch: 205   Cost: 1.250593090520763
# Batch Gradient Descent Epoch: 206   Cost: 1.2482749007417058
# Batch Gradient Descent Epoch: 207   Cost: 1.245963354920476
# Batch Gradient Descent Epoch: 208   Cost: 1.2436584219313849
# Batch Gradient Descent Epoch: 209   Cost: 1.2413600622192045
# Batch Gradient Descent Epoch: 210   Cost: 1.2390682274307843
# Batch Gradient Descent Epoch: 211   Cost: 1.2367828600680617
# Batch Gradient Descent Epoch: 212   Cost: 1.2345038931814303
# Batch Gradient Descent Epoch: 213   Cost: 1.2322312501181834
# Batch Gradient Descent Epoch: 214   Cost: 1.2299648443383304
# Batch Gradient Descent Epoch: 215   Cost: 1.2277045793195465
# Batch Gradient Descent Epoch: 216   Cost: 1.2254503485613377
# Batch Gradient Descent Epoch: 217   Cost: 1.2232020357140112
# Batch Gradient Descent Epoch: 218   Cost: 1.2209595148441201
# Batch Gradient Descent Epoch: 219   Cost: 1.2187226508654754
# Batch Gradient Descent Epoch: 220   Cost: 1.2164913001471318
# Batch Gradient Descent Epoch: 221   Cost: 1.2142653113173407
# Batch Gradient Descent Epoch: 222   Cost: 1.212044526277048
# Batch Gradient Descent Epoch: 223   Cost: 1.2098287814203197
# Batch Gradient Descent Epoch: 224   Cost: 1.2076179090593115
# Batch Gradient Descent Epoch: 225   Cost: 1.2054117390346564
# Batch Gradient Descent Epoch: 226   Cost: 1.2032101004747378
# Batch Gradient Descent Epoch: 227   Cost: 1.2010128236650137
# Batch Gradient Descent Epoch: 228   Cost: 1.198819741963446
# Batch Gradient Descent Epoch: 229   Cost: 1.196630693700226
# Batch Gradient Descent Epoch: 230   Cost: 1.194445523991002
# Batch Gradient Descent Epoch: 231   Cost: 1.192264086392086
# Batch Gradient Descent Epoch: 232   Cost: 1.190086244338815
# Batch Gradient Descent Epoch: 233   Cost: 1.1879118723145883
# Batch Gradient Descent Epoch: 234   Cost: 1.1857408567205598
# Batch Gradient Descent Epoch: 235   Cost: 1.1835730964248292
# Batch Gradient Descent Epoch: 236   Cost: 1.1814085030019077
# Batch Gradient Descent Epoch: 237   Cost: 1.1792470006789482
# Batch Gradient Descent Epoch: 238   Cost: 1.1770885260258837
# Batch Gradient Descent Epoch: 239   Cost: 1.1749330274349217
# Batch Gradient Descent Epoch: 240   Cost: 1.1727804644395943
# Batch Gradient Descent Epoch: 241   Cost: 1.170630806928636
# Batch Gradient Descent Epoch: 242   Cost: 1.1684840342999951
# Batch Gradient Descent Epoch: 243   Cost: 1.1663401346076596
# Batch Gradient Descent Epoch: 244   Cost: 1.1641991037283361
# Batch Gradient Descent Epoch: 245   Cost: 1.1620609445816343
# Batch Gradient Descent Epoch: 246   Cost: 1.159925666416302
# Batch Gradient Descent Epoch: 247   Cost: 1.1577932841668008
# Batch Gradient Descent Epoch: 248   Cost: 1.1556638178764402
# Batch Gradient Descent Epoch: 249   Cost: 1.1535372921722151
# Batch Gradient Descent Epoch: 250   Cost: 1.1514137357703678
# Batch Gradient Descent Epoch: 251   Cost: 1.149293180993486
# Batch Gradient Descent Epoch: 252   Cost: 1.1471756632709573
# Batch Gradient Descent Epoch: 253   Cost: 1.145061220607258
# Batch Gradient Descent Epoch: 254   Cost: 1.1429498930061621
# Batch Gradient Descent Epoch: 255   Cost: 1.1408417218403084
# Batch Gradient Descent Epoch: 256   Cost: 1.1387367491785014
# Batch Gradient Descent Epoch: 257   Cost: 1.1366350170775232
# Batch Gradient Descent Epoch: 258   Cost: 1.134536566867219
# Batch Gradient Descent Epoch: 259   Cost: 1.132441438448752
# Batch Gradient Descent Epoch: 260   Cost: 1.130349669644647
# Batch Gradient Descent Epoch: 261   Cost: 1.128261295622641
# Batch Gradient Descent Epoch: 262   Cost: 1.1261763484252347
# Batch Gradient Descent Epoch: 263   Cost: 1.1240948566192188
# Batch Gradient Descent Epoch: 264   Cost: 1.122016845079816
# Batch Gradient Descent Epoch: 265   Cost: 1.1199423349077209
# Batch Gradient Descent Epoch: 266   Cost: 1.1178713434699628
# Batch Gradient Descent Epoch: 267   Cost: 1.115803884553006
# Batch Gradient Descent Epoch: 268   Cost: 1.113739968597818
# Batch Gradient Descent Epoch: 269   Cost: 1.111679602994231
# Batch Gradient Descent Epoch: 270   Cost: 1.1096227924038087
# Batch Gradient Descent Epoch: 271   Cost: 1.1075695390820854
# Batch Gradient Descent Epoch: 272   Cost: 1.1055198431757898
# Batch Gradient Descent Epoch: 273   Cost: 1.1034737029703152
# Batch Gradient Descent Epoch: 274   Cost: 1.1014311150793519
# Batch Gradient Descent Epoch: 275   Cost: 1.09939207455438
# Batch Gradient Descent Epoch: 276   Cost: 1.097356574927562
# Batch Gradient Descent Epoch: 277   Cost: 1.095324608171775
# Batch Gradient Descent Epoch: 278   Cost: 1.0932961646076123
# Batch Gradient Descent Epoch: 279   Cost: 1.0912712327438359
# Batch Gradient Descent Epoch: 280   Cost: 1.0892497990939711
# Batch Gradient Descent Epoch: 281   Cost: 1.0872318479595924
# Batch Gradient Descent Epoch: 282   Cost: 1.0852173612278866
# Batch Gradient Descent Epoch: 283   Cost: 1.0832063181637337
# Batch Gradient Descent Epoch: 284   Cost: 1.0811986952640837
# Batch Gradient Descent Epoch: 285   Cost: 1.079194466127063
# Batch Gradient Descent Epoch: 286   Cost: 1.0771936014239856
# Batch Gradient Descent Epoch: 287   Cost: 1.0751960688952515
# Batch Gradient Descent Epoch: 288   Cost: 1.073201833486264
# Batch Gradient Descent Epoch: 289   Cost: 1.071210857495551
# Batch Gradient Descent Epoch: 290   Cost: 1.0692231008966726
# Batch Gradient Descent Epoch: 291   Cost: 1.067238521638046
# Batch Gradient Descent Epoch: 292   Cost: 1.0652570761528406
# Batch Gradient Descent Epoch: 293   Cost: 1.0632787197829752
# Batch Gradient Descent Epoch: 294   Cost: 1.0613034074588685
# Batch Gradient Descent Epoch: 295   Cost: 1.059331094198648
# Batch Gradient Descent Epoch: 296   Cost: 1.0573617359267582
# Batch Gradient Descent Epoch: 297   Cost: 1.0553952899707777
# Batch Gradient Descent Epoch: 298   Cost: 1.0534317159894513
# Batch Gradient Descent Epoch: 299   Cost: 1.0514709763668233
# Batch Gradient Descent Epoch: 300   Cost: 1.0495130372223902
# Batch Gradient Descent Epoch: 301   Cost: 1.0475578685827616
# Batch Gradient Descent Epoch: 302   Cost: 1.0456054454684716
# Batch Gradient Descent Epoch: 303   Cost: 1.0436557476973407
# Batch Gradient Descent Epoch: 304   Cost: 1.0417087610923648
# Batch Gradient Descent Epoch: 305   Cost: 1.0397644767256913
# Batch Gradient Descent Epoch: 306   Cost: 1.037822892376926
# Batch Gradient Descent Epoch: 307   Cost: 1.0358840109663539
# Batch Gradient Descent Epoch: 308   Cost: 1.0339478425197595
# Batch Gradient Descent Epoch: 309   Cost: 1.032014401421559
# Batch Gradient Descent Epoch: 310   Cost: 1.0300837093580317
# Batch Gradient Descent Epoch: 311   Cost: 1.0281557908041614
# Batch Gradient Descent Epoch: 312   Cost: 1.0262306777536048
# Batch Gradient Descent Epoch: 313   Cost: 1.0243084024673286
# Batch Gradient Descent Epoch: 314   Cost: 1.0223890053618359
# Batch Gradient Descent Epoch: 315   Cost: 1.020472523346708
# Batch Gradient Descent Epoch: 316   Cost: 1.0185590031984517
# Batch Gradient Descent Epoch: 317   Cost: 1.0166484825804893
# Batch Gradient Descent Epoch: 318   Cost: 1.014741012889661
# Batch Gradient Descent Epoch: 319   Cost: 1.0128366278452263
# Batch Gradient Descent Epoch: 320   Cost: 1.0109353827338097
# Batch Gradient Descent Epoch: 321   Cost: 1.0090373015269118
# Batch Gradient Descent Epoch: 322   Cost: 1.0071424446861257
# Batch Gradient Descent Epoch: 323   Cost: 1.0052508187218416
# Batch Gradient Descent Epoch: 324   Cost: 1.0033624941600205
# Batch Gradient Descent Epoch: 325   Cost: 1.0014774487038736
# Batch Gradient Descent Epoch: 326   Cost: 0.9995957741378034
# Batch Gradient Descent Epoch: 327   Cost: 0.9977174009813775
# Batch Gradient Descent Epoch: 328   Cost: 0.9958424646052083
# Batch Gradient Descent Epoch: 329   Cost: 0.9939708164432665
# Batch Gradient Descent Epoch: 330   Cost: 0.99210267784692
# Batch Gradient Descent Epoch: 331   Cost: 0.9902377634271161
# Batch Gradient Descent Epoch: 332   Cost: 0.9883764598167476
# Batch Gradient Descent Epoch: 333   Cost: 0.986518237837443
# Batch Gradient Descent Epoch: 334   Cost: 0.9846637977558299
# Batch Gradient Descent Epoch: 335   Cost: 0.9828121656286071
# Batch Gradient Descent Epoch: 336   Cost: 0.9809646347057508
# Batch Gradient Descent Epoch: 337   Cost: 0.9791194047566287
# Batch Gradient Descent Epoch: 338   Cost: 0.9772788928579592
# Batch Gradient Descent Epoch: 339   Cost: 0.9754397415160715
# Batch Gradient Descent Epoch: 340   Cost: 0.973606510575483
# Batch Gradient Descent Epoch: 341   Cost: 0.9717728717826826
# Batch Gradient Descent Epoch: 342   Cost: 0.9699475040038402
# Batch Gradient Descent Epoch: 343   Cost: 0.9681183486033391
# Batch Gradient Descent Epoch: 344   Cost: 0.9663020771261047
# Batch Gradient Descent Epoch: 345   Cost: 0.9644754585585
# Batch Gradient Descent Epoch: 346   Cost: 0.9626708317483689
# Batch Gradient Descent Epoch: 347   Cost: 0.9608429489380459
# Batch Gradient Descent Epoch: 348   Cost: 0.9590551885434668
# Batch Gradient Descent Epoch: 349   Cost: 0.9572184408425397
# Stochastic Gradient Descent Epoch: 0   Cost: 1.1148845374327065
# Momentum Gradient Descent Epoch: 0   Cost: 1.133979917735744
# Momentum Gradient Descent Epoch: 1   Cost: 1.0205352529353815
# Momentum Gradient Descent Epoch: 2   Cost: 0.9923308926709308
# Momentum Gradient Descent Epoch: 3   Cost: 1.2289765873815974
# Momentum Gradient Descent Epoch: 4   Cost: 0.9803912497148813
# Momentum Gradient Descent Epoch: 5   Cost: 0.9445045265730658
# Momentum Gradient Descent Epoch: 6   Cost: 1.220775411065718
# Momentum Gradient Descent Epoch: 7   Cost: 0.9412275101544698
# Momentum Gradient Descent Epoch: 8   Cost: 0.9187625607434461
# Momentum Gradient Descent Epoch: 9   Cost: 1.157181977038132
# Momentum Gradient Descent Epoch: 10   Cost: 0.9099102450433785
# Momentum Gradient Descent Epoch: 11   Cost: 0.8896123088492359
# Momentum Gradient Descent Epoch: 12   Cost: 1.0864362759848185
# Momentum Gradient Descent Epoch: 13   Cost: 0.8863581857088341
# Momentum Gradient Descent Epoch: 14   Cost: 0.8604515480567605
# Momentum Gradient Descent Epoch: 15   Cost: 1.0080068737819572
# Momentum Gradient Descent Epoch: 16   Cost: 0.8776972343093181
# Momentum Gradient Descent Epoch: 17   Cost: 0.8637547137649642
# Momentum Gradient Descent Epoch: 18   Cost: 0.8802315040181721
# Momentum Gradient Descent Epoch: 19   Cost: 0.8492268737431925
# Momentum Gradient Descent Epoch: 20   Cost: 0.9260009849167758
# Momentum Gradient Descent Epoch: 21   Cost: 0.7773363300762588
# Momentum Gradient Descent Epoch: 22   Cost: 0.7623125129386782
# Momentum Gradient Descent Epoch: 23   Cost: 0.8339964119024179
# Momentum Gradient Descent Epoch: 24   Cost: 0.8007602193515474
# Momentum Gradient Descent Epoch: 25   Cost: 0.9325777319304124
# Momentum Gradient Descent Epoch: 26   Cost: 0.8643295434633969
# Momentum Gradient Descent Epoch: 27   Cost: 1.1388630909433863
# Momentum Gradient Descent Epoch: 28   Cost: 1.2836293741619387
# Momentum Gradient Descent Epoch: 29   Cost: 4.112684745249766
# Momentum Gradient Descent Epoch: 30   Cost: 7.692137914382771
# Momentum Gradient Descent Epoch: 31   Cost: 55.292023315837156
# Momentum Gradient Descent Epoch: 32   Cost: 12.878421050767495
# Momentum Gradient Descent Epoch: 33   Cost: 8.059047825187223
# Momentum Gradient Descent Epoch: 34   Cost: 8.059047825187223
# Momentum Gradient Descent Epoch: 35   Cost: 34.504736231759445
# Momentum Gradient Descent Epoch: 36   Cost: 48.84947720466163
# Momentum Gradient Descent Epoch: 37   Cost: 3.9668458217023
# Momentum Gradient Descent Epoch: 38   Cost: 6.156944032842068
# Momentum Gradient Descent Epoch: 39   Cost: 11.40220374832613
# Momentum Gradient Descent Epoch: 40   Cost: 25.843351919626308
# Momentum Gradient Descent Epoch: 41   Cost: 1.7684226097666582
# Momentum Gradient Descent Epoch: 42   Cost: 4.594162707719608
# Momentum Gradient Descent Epoch: 43   Cost: 1.9800147328535986
# Momentum Gradient Descent Epoch: 44   Cost: 7.599502785384472
# Momentum Gradient Descent Epoch: 45   Cost: 14.611788811778231
# Momentum Gradient Descent Epoch: 46   Cost: 4.3187732879299405
# Momentum Gradient Descent Epoch: 47   Cost: 2.038038825981377
# Momentum Gradient Descent Epoch: 48   Cost: 2.5719954441975266
# Momentum Gradient Descent Epoch: 49   Cost: 1.9944001889972973
# Momentum Gradient Descent Epoch: 50   Cost: 5.1842606026797045
# Momentum Gradient Descent Epoch: 51   Cost: 9.0417777612257
# Momentum Gradient Descent Epoch: 52   Cost: 5.514851040229992
# Momentum Gradient Descent Epoch: 53   Cost: 2.3597956298302116
# Momentum Gradient Descent Epoch: 54   Cost: 2.0833215752251766
# Momentum Gradient Descent Epoch: 55   Cost: 2.057095883858294
# Momentum Gradient Descent Epoch: 56   Cost: 2.6881773227527663
# Momentum Gradient Descent Epoch: 57   Cost: 5.0684107351983005
# Momentum Gradient Descent Epoch: 58   Cost: nan
# Momentum Gradient Descent Epoch: 59   Cost: 4.325375568374346
# Momentum Gradient Descent Epoch: 60   Cost: 2.5590034270658735
# Momentum Gradient Descent Epoch: 61   Cost: 2.114575675374373
# Momentum Gradient Descent Epoch: 62   Cost: 2.144330769354427
# Momentum Gradient Descent Epoch: 63   Cost: 2.68526442231083
# Momentum Gradient Descent Epoch: 64   Cost: 4.035489530781438
# Momentum Gradient Descent Epoch: 65   Cost: nan
# Momentum Gradient Descent Epoch: 66   Cost: 4.09724289028215
# Momentum Gradient Descent Epoch: 67   Cost: 2.8606650244888536
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in power
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:66: RuntimeWarning: divide by zero encountered in log
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in multiply
# Momentum Gradient Descent Epoch: 68   Cost: 2.3043074009683546
# Momentum Gradient Descent Epoch: 69   Cost: 2.2545663550493225
# Momentum Gradient Descent Epoch: 70   Cost: 2.583654798466653
# Momentum Gradient Descent Epoch: 71   Cost: 3.410204130381188
# Momentum Gradient Descent Epoch: 72   Cost: 4.109124924348271
# Momentum Gradient Descent Epoch: 73   Cost: 3.829638153924724
# Momentum Gradient Descent Epoch: 74   Cost: 3.0190860313167027
# Momentum Gradient Descent Epoch: 75   Cost: 2.463006021299585
# Momentum Gradient Descent Epoch: 76   Cost: 2.3450178879579306
# Momentum Gradient Descent Epoch: 77   Cost: 2.5507307632411114
# Momentum Gradient Descent Epoch: 78   Cost: 3.0812967601866093
# Momentum Gradient Descent Epoch: 79   Cost: 3.5533500329952363
# Momentum Gradient Descent Epoch: 80   Cost: 3.4911249013272596
# Momentum Gradient Descent Epoch: 81   Cost: 2.9914685997638126
# Momentum Gradient Descent Epoch: 82   Cost: 2.5351715510206856
# Momentum Gradient Descent Epoch: 83   Cost: 2.378646328936376
# Momentum Gradient Descent Epoch: 84   Cost: 2.4963783022460917
# Momentum Gradient Descent Epoch: 85   Cost: 2.842653472053662
# Momentum Gradient Descent Epoch: 86   Cost: 3.15852619586624
# Momentum Gradient Descent Epoch: 87   Cost: 3.155948214604065
# Momentum Gradient Descent Epoch: 88   Cost: 2.85101894435
# Momentum Gradient Descent Epoch: 89   Cost: 2.5199650611514866
# Momentum Gradient Descent Epoch: 90   Cost: 2.3850574876630057
# Momentum Gradient Descent Epoch: 91   Cost: 2.459052439455862
# Momentum Gradient Descent Epoch: 92   Cost: 2.689307391208683
# Momentum Gradient Descent Epoch: 93   Cost: 2.8875351568574006
# Momentum Gradient Descent Epoch: 94   Cost: 2.8827912230043964
# Momentum Gradient Descent Epoch: 95   Cost: 2.684525136436039
# Momentum Gradient Descent Epoch: 96   Cost: 2.4580498493611
# Momentum Gradient Descent Epoch: 97   Cost: 2.3643104670802355
# Momentum Gradient Descent Epoch: 98   Cost: 2.4210897362950687
# Momentum Gradient Descent Epoch: 99   Cost: 2.5792093821691036
# Momentum Gradient Descent Epoch: 100   Cost: 2.694584774543919
# Momentum Gradient Descent Epoch: 101   Cost: 2.664038685474133
# Momentum Gradient Descent Epoch: 102   Cost: 2.5149745180290264
# Momentum Gradient Descent Epoch: 103   Cost: 2.3644623963375433
# Momentum Gradient Descent Epoch: 104   Cost: 2.3103116921142317
# Momentum Gradient Descent Epoch: 105   Cost: 2.364707872344495
# Momentum Gradient Descent Epoch: 106   Cost: 2.4697605612314786
# Momentum Gradient Descent Epoch: 107   Cost: 2.525909152834449
# Momentum Gradient Descent Epoch: 108   Cost: 2.480677184655891
# Momentum Gradient Descent Epoch: 109   Cost: 2.3676140182536654
# Momentum Gradient Descent Epoch: 110   Cost: 2.269875561124882
# Momentum Gradient Descent Epoch: 111   Cost: 2.2457039627119273
# Momentum Gradient Descent Epoch: 112   Cost: 2.2940202977322093
# Momentum Gradient Descent Epoch: 113   Cost: 2.358032013078672
# Momentum Gradient Descent Epoch: 114   Cost: 2.376944662239391
# Momentum Gradient Descent Epoch: 115   Cost: 2.327946462447233
# Momentum Gradient Descent Epoch: 116   Cost: 2.2451210514229367
# Momentum Gradient Descent Epoch: 117   Cost: 2.1813531434715374
# Momentum Gradient Descent Epoch: 118   Cost: 2.1734846158261214
# Momentum Gradient Descent Epoch: 119   Cost: 2.2102543221006257
# Momentum Gradient Descent Epoch: 120   Cost: 2.2447731607276493
# Momentum Gradient Descent Epoch: 121   Cost: 2.2385904350801225
# Momentum Gradient Descent Epoch: 122   Cost: 2.1884718409142336
# Momentum Gradient Descent Epoch: 123   Cost: 2.127158520551521
# Momentum Gradient Descent Epoch: 124   Cost: 2.096618085599525
# Momentum Gradient Descent Epoch: 125   Cost: 2.1087139075690917
# Momentum Gradient Descent Epoch: 126   Cost: 2.1371601319461893
# Momentum Gradient Descent Epoch: 127   Cost: 2.1403549653154044
# Momentum Gradient Descent Epoch: 128   Cost: 2.104863660742439
# Momentum Gradient Descent Epoch: 129   Cost: 2.055838506310093
# Momentum Gradient Descent Epoch: 130   Cost: 2.029384520146606
# Momentum Gradient Descent Epoch: 131   Cost: 2.0351352326032295
# Momentum Gradient Descent Epoch: 132   Cost: 2.0527324018426647
# Momentum Gradient Descent Epoch: 133   Cost: 2.052260255719958
# Momentum Gradient Descent Epoch: 134   Cost: 2.0236196938043274
# Momentum Gradient Descent Epoch: 135   Cost: 1.9856454956089356
# Momentum Gradient Descent Epoch: 136   Cost: 1.9632882829957838
# Momentum Gradient Descent Epoch: 137   Cost: 1.963699639932969
# Momentum Gradient Descent Epoch: 138   Cost: 1.972715648444953
# Momentum Gradient Descent Epoch: 139   Cost: 1.968468600791538
# Momentum Gradient Descent Epoch: 140   Cost: 1.943498183824297
# Momentum Gradient Descent Epoch: 141   Cost: 1.912818579559117
# Momentum Gradient Descent Epoch: 142   Cost: 1.8953158913345012
# Momentum Gradient Descent Epoch: 143   Cost: 1.8945947106125904
# Momentum Gradient Descent Epoch: 144   Cost: 1.8968668980814227
# Momentum Gradient Descent Epoch: 145   Cost: 1.885005966063835
# Momentum Gradient Descent Epoch: 146   Cost: 1.8592900795181182
# Momentum Gradient Descent Epoch: 147   Cost: 1.8364245603448064
# Momentum Gradient Descent Epoch: 148   Cost: 1.8280162942530056
# Momentum Gradient Descent Epoch: 149   Cost: 1.8281230544574225
# Nesterov Gradient Descent Epoch: 0   Cost: 1.7637756363005106
# Nesterov Gradient Descent Epoch: 1   Cost: 1.7362664514052502
# Nesterov Gradient Descent Epoch: 2   Cost: 1.7578061221789556
# Nesterov Gradient Descent Epoch: 3   Cost: 1.7354586270633987
# Nesterov Gradient Descent Epoch: 4   Cost: 1.7461165653098492
# Nesterov Gradient Descent Epoch: 5   Cost: 1.7284261994189918
# Nesterov Gradient Descent Epoch: 6   Cost: 1.7329096256383878
# Nesterov Gradient Descent Epoch: 7   Cost: 1.7179508038752302
# Nesterov Gradient Descent Epoch: 8   Cost: 1.7184757416546752
# Nesterov Gradient Descent Epoch: 9   Cost: 1.7051588279333247
# Nesterov Gradient Descent Epoch: 10   Cost: 1.7029742187419388
# Nesterov Gradient Descent Epoch: 11   Cost: 1.6907267561420356
# Nesterov Gradient Descent Epoch: 12   Cost: 1.6866130078479613
# Nesterov Gradient Descent Epoch: 13   Cost: 1.6750566644447744
# Nesterov Gradient Descent Epoch: 14   Cost: 1.6695583801379799
# Nesterov Gradient Descent Epoch: 15   Cost: 1.6583593156029464
# Nesterov Gradient Descent Epoch: 16   Cost: 1.6518867154750414
# Nesterov Gradient Descent Epoch: 17   Cost: 1.6407455762114693
# Nesterov Gradient Descent Epoch: 18   Cost: 1.6336302701588976
# Nesterov Gradient Descent Epoch: 19   Cost: 1.6223220871480795
# Nesterov Gradient Descent Epoch: 20   Cost: 1.6148621682478748
# Nesterov Gradient Descent Epoch: 21   Cost: 1.6032370639779714
# Nesterov Gradient Descent Epoch: 22   Cost: 1.5957117263964729
# Nesterov Gradient Descent Epoch: 23   Cost: 1.5836461072002248
# Nesterov Gradient Descent Epoch: 24   Cost: 1.5763475922558805
# Nesterov Gradient Descent Epoch: 25   Cost: 1.5637261446532953
# Nesterov Gradient Descent Epoch: 26   Cost: 1.5569880072555324
# Nesterov Gradient Descent Epoch: 27   Cost: 1.5436543174196038
# Nesterov Gradient Descent Epoch: 28   Cost: 1.5378313686350737
# Nesterov Gradient Descent Epoch: 29   Cost: 1.523479820193864
# Nesterov Gradient Descent Epoch: 30   Cost: 1.5190512940308862
# Nesterov Gradient Descent Epoch: 31   Cost: 1.5030799634050729
# Nesterov Gradient Descent Epoch: 32   Cost: 1.5009065960795642
# Nesterov Gradient Descent Epoch: 33   Cost: 1.482099870382092
# Nesterov Gradient Descent Epoch: 34   Cost: 1.4839451372583845
# Nesterov Gradient Descent Epoch: 35   Cost: 1.459742344787484
# Nesterov Gradient Descent Epoch: 36   Cost: 1.469502004229918
# Nesterov Gradient Descent Epoch: 37   Cost: 1.4342412713216663
# Nesterov Gradient Descent Epoch: 38   Cost: 1.460985304746292
# Nesterov Gradient Descent Epoch: 39   Cost: 1.4016660661296871
# Nesterov Gradient Descent Epoch: 40   Cost: 1.4676925168575632
# Nesterov Gradient Descent Epoch: 41   Cost: 1.3544676425242665
# Nesterov Gradient Descent Epoch: 42   Cost: 1.5163009729660284
# Nesterov Gradient Descent Epoch: 43   Cost: 1.2866573842049025
# Nesterov Gradient Descent Epoch: 44   Cost: 1.6691438694385645
# Nesterov Gradient Descent Epoch: 45   Cost: 1.2251268363178216
# Nesterov Gradient Descent Epoch: 46   Cost: 2.478016061416913
# Nesterov Gradient Descent Epoch: 47   Cost: 1.7297100927837983
# Nesterov Gradient Descent Epoch: 48   Cost: 13.481115483987903
# Nesterov Gradient Descent Epoch: 49   Cost: 6.863652228026794
# Nesterov Gradient Descent Epoch: 50   Cost: 106.31687238606987
# Nesterov Gradient Descent Epoch: 51   Cost: 2.825533388359335
# Nesterov Gradient Descent Epoch: 52   Cost: 16.37665635011269
# Nesterov Gradient Descent Epoch: 53   Cost: 6.5221323877772805
# Nesterov Gradient Descent Epoch: 54   Cost: 84.20984109873294
# Nesterov Gradient Descent Epoch: 55   Cost: 3.426318595572495
# Nesterov Gradient Descent Epoch: 56   Cost: 13.471649506623965
# Nesterov Gradient Descent Epoch: 57   Cost: 2.6257340740841864
# Nesterov Gradient Descent Epoch: 58   Cost: 7.0910937318120055
# Nesterov Gradient Descent Epoch: 59   Cost: 1.5988824913743476
# Nesterov Gradient Descent Epoch: 60   Cost: 2.1466306299996423
# Nesterov Gradient Descent Epoch: 61   Cost: 2.272625509528228
# Nesterov Gradient Descent Epoch: 62   Cost: 2.2734960985634
# Nesterov Gradient Descent Epoch: 63   Cost: 2.2813207100677713
# Nesterov Gradient Descent Epoch: 64   Cost: 2.3087236620961127
# Nesterov Gradient Descent Epoch: 65   Cost: 2.3404204631130963
# Nesterov Gradient Descent Epoch: 66   Cost: 2.3663185201020758
# Nesterov Gradient Descent Epoch: 67   Cost: 2.386063146694455
# Nesterov Gradient Descent Epoch: 68   Cost: 2.4017030803934905
# Nesterov Gradient Descent Epoch: 69   Cost: 2.4144363042581856
# Nesterov Gradient Descent Epoch: 70   Cost: 2.424627370712034
# Nesterov Gradient Descent Epoch: 71   Cost: 2.4324131359708336
# Nesterov Gradient Descent Epoch: 72   Cost: 2.437972570895554
# Nesterov Gradient Descent Epoch: 73   Cost: 2.441528303927992
# Nesterov Gradient Descent Epoch: 74   Cost: 2.4432947819434436
# Nesterov Gradient Descent Epoch: 75   Cost: 2.443454909111962
# Nesterov Gradient Descent Epoch: 76   Cost: 2.4421607242223344
# Nesterov Gradient Descent Epoch: 77   Cost: 2.4395415591925116
# Nesterov Gradient Descent Epoch: 78   Cost: 2.435712724367221
# Nesterov Gradient Descent Epoch: 79   Cost: 2.430779934793292
# Nesterov Gradient Descent Epoch: 80   Cost: 2.424833090295721
# Nesterov Gradient Descent Epoch: 81   Cost: 2.417934515733344
# Nesterov Gradient Descent Epoch: 82   Cost: 2.410123937797001
# Nesterov Gradient Descent Epoch: 83   Cost: 2.40145173082164
# Nesterov Gradient Descent Epoch: 84   Cost: 2.392017852960642
# Nesterov Gradient Descent Epoch: 85   Cost: 2.381991983253329
# Nesterov Gradient Descent Epoch: 86   Cost: 2.3716137599111553
# Nesterov Gradient Descent Epoch: 87   Cost: 2.3611392581830466
# Nesterov Gradient Descent Epoch: 88   Cost: 2.350707227481296
# Nesterov Gradient Descent Epoch: 89   Cost: 2.340239879690348
# Nesterov Gradient Descent Epoch: 90   Cost: 2.329495142556404
# Nesterov Gradient Descent Epoch: 91   Cost: 2.3182069711247864
# Nesterov Gradient Descent Epoch: 92   Cost: 2.3062033728485494
# Nesterov Gradient Descent Epoch: 93   Cost: 2.29349844545071
# Nesterov Gradient Descent Epoch: 94   Cost: 2.280270318848744
# Nesterov Gradient Descent Epoch: 95   Cost: 2.266616565818968
# Nesterov Gradient Descent Epoch: 96   Cost: 2.252482076325871
# Nesterov Gradient Descent Epoch: 97   Cost: 2.2379134585121694
# Nesterov Gradient Descent Epoch: 98   Cost: 2.2231710166823553
# Nesterov Gradient Descent Epoch: 99   Cost: 2.208536762394314
# Nesterov Gradient Descent Epoch: 100   Cost: 2.1941632036209273
# Nesterov Gradient Descent Epoch: 101   Cost: 2.180086081722204
# Nesterov Gradient Descent Epoch: 102   Cost: 2.166265786768259
# Nesterov Gradient Descent Epoch: 103   Cost: 2.1526430513188335
# Nesterov Gradient Descent Epoch: 104   Cost: 2.1392013869479745
# Nesterov Gradient Descent Epoch: 105   Cost: 2.1259588147779707
# Nesterov Gradient Descent Epoch: 106   Cost: 2.112915261801191
# Nesterov Gradient Descent Epoch: 107   Cost: 2.100040557223594
# Nesterov Gradient Descent Epoch: 108   Cost: 2.0873018216960033
# Nesterov Gradient Descent Epoch: 109   Cost: 2.074680120997213
# Nesterov Gradient Descent Epoch: 110   Cost: 2.0621555538986778
# Nesterov Gradient Descent Epoch: 111   Cost: 2.0496966464229622
# Nesterov Gradient Descent Epoch: 112   Cost: 2.03729061660749
# Nesterov Gradient Descent Epoch: 113   Cost: 2.024945316848013
# Nesterov Gradient Descent Epoch: 114   Cost: 2.0126462654118438
# Nesterov Gradient Descent Epoch: 115   Cost: 2.000379439203464
# Nesterov Gradient Descent Epoch: 116   Cost: 1.988176396342553
# Nesterov Gradient Descent Epoch: 117   Cost: 1.976039398831655
# Nesterov Gradient Descent Epoch: 118   Cost: 1.963871384832629
# Nesterov Gradient Descent Epoch: 119   Cost: 1.951605598074177
# Nesterov Gradient Descent Epoch: 120   Cost: 1.9393199778494372
# Nesterov Gradient Descent Epoch: 121   Cost: 1.927088619842601
# Nesterov Gradient Descent Epoch: 122   Cost: 1.9148724705916491
# Nesterov Gradient Descent Epoch: 123   Cost: 1.902609782551909
# Nesterov Gradient Descent Epoch: 124   Cost: 1.8902924876960123
# Nesterov Gradient Descent Epoch: 125   Cost: 1.8779639348589394
# Nesterov Gradient Descent Epoch: 126   Cost: 1.8656858894773924
# Nesterov Gradient Descent Epoch: 127   Cost: 1.8535054471701806
# Nesterov Gradient Descent Epoch: 128   Cost: 1.84143854933864
# Nesterov Gradient Descent Epoch: 129   Cost: 1.8294751102534934
# Nesterov Gradient Descent Epoch: 130   Cost: 1.8175938146127064
# Nesterov Gradient Descent Epoch: 131   Cost: 1.8057752910843743
# Nesterov Gradient Descent Epoch: 132   Cost: 1.7940113306760734
# Nesterov Gradient Descent Epoch: 133   Cost: 1.7823110573700827
# Nesterov Gradient Descent Epoch: 134   Cost: 1.7707070832509395
# Nesterov Gradient Descent Epoch: 135   Cost: 1.759251896854081
# Nesterov Gradient Descent Epoch: 136   Cost: 1.7479860244649519
# Nesterov Gradient Descent Epoch: 137   Cost: 1.7369009332566898
# Nesterov Gradient Descent Epoch: 138   Cost: 1.7259439066690387
# Nesterov Gradient Descent Epoch: 139   Cost: 1.7150598514015383
# Nesterov Gradient Descent Epoch: 140   Cost: 1.7042214805354248
# Nesterov Gradient Descent Epoch: 141   Cost: 1.6934261326170295
# Nesterov Gradient Descent Epoch: 142   Cost: 1.6826797937477291
# Nesterov Gradient Descent Epoch: 143   Cost: 1.6719837448296553
# Nesterov Gradient Descent Epoch: 144   Cost: 1.6613271463347439
# Nesterov Gradient Descent Epoch: 145   Cost: 1.6506944220942064
# Nesterov Gradient Descent Epoch: 146   Cost: 1.6400823539605092
# Nesterov Gradient Descent Epoch: 147   Cost: 1.6295063741306222
# Nesterov Gradient Descent Epoch: 148   Cost: 1.6189859759154412
# Nesterov Gradient Descent Epoch: 149   Cost: 1.6085299281329515

# %% [markdown]
# 4. Overall, the momentum gradient descent performs better. They both converge to their minimum values at around the same time, but the Momentum Gradient Descent has a much smaller final cost. Momentum also happens to have an overflow error at some point, although this does not impact the final result. However, when compared to Vanilla Gradient Descent, they are both much faster overall. Optimization algorithms are useful for this dataset, but it is also small enough that it is not a significant time difference.
